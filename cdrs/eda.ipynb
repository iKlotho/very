# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("Call_Records_from_2018-09-04_00_00_00_to_2018-09-04_07_44_56.xls")

# %%
df.head()
# Out:
#               Caller  Original CLI           CLI  Original CLD           CLD  \
# 0  Acct. AKARTELEKOM  905531631539  905531631539  998902990944  998902990944
# 1         Acct. BICS  905428900360  905428900360  903922236464  903922236464
# 2  Acct. AKARTELEKOM   02163497846  902163497846  998712235059  998712235059
# 3     Acct. QUICKCOM  989190045526  989190045526   93779767327   93779767327
# 4       Acct. GURKON   08507990064  908507990064  903926602000  903926602000
#
#                Billing Prefix      Country                    Description  \
# 0  external_translation_error   UZBEKISTAN  Uzbekistan - Mobile - Beeline
# 1  external_translation_error       TURKEY          Turkey - North Cyprus
# 2  external_translation_error   UZBEKISTAN          Uzbekistan - Tashkent
# 3                        9377  AFGHANISTAN     Afghanistan - Mobile - MTN
# 4  external_translation_error       TURKEY          Turkey - North Cyprus
#
#            Setup Time        Connect Time  \
# ...

# %%
from IPython.display import HTML, display
import tabulate

# %%
df.columns
# Out:
# Index(['Caller', 'Original CLI', 'CLI', 'Original CLD', 'CLD',
#        'Billing Prefix', 'Country', 'Description', 'Setup Time',
#        'Connect Time', 'Disconnect Time', 'Duration, sec',
#        'Billed Duration, sec', 'Cost', 'Currency', 'Result', 'Remote IP',
#        'LRN Original CLD', 'LRN CLD', 'Area Name', 'Error Message'],
#       dtype='object')

# %%
df[["Result","Error Message"]].drop_duplicates().sort_values(by="Result",ascending=False).reset_index()[["Result","Error Message"]]
# Out:
#    Result                            Error Message
# 0       0                                       OK
# 1     -14                  No Rate Found In Tariff
# 2     -15                       Call Loop Detected
# 3     -20                     Insufficient Balance
# 4     -21                 Destination Is Forbidden
# 5     -23                          Loss Protection
# 6     -24                    Address Is Incomplete
# 7     -25                          No Routes Found
# 8     -30  Call has been canceled by calling party

# %%
df.groupby("Result").count()
# Out:
#         Caller  Original CLI    CLI  Original CLD    CLD  Billing Prefix  \
# Result
# -30      32786         32763  32763         32786  32786           32786
# -25         26            26     26            26     26              26
# -24        916           916    916           916    916             916
# -23        327           327    327           327    327             327
# -21        943           943    943           943    943             943
# -20       1377          1377   1377          1377   1377            1377
# -15        556           556    556           556    556             556
# -14         57            57     57            57     57              57
#  0       13643         13631  13631         13643  13643           13643
#
#         Country  Description  Setup Time  Connect Time  Disconnect Time  \
# Result
# -30       32786        32786       32786         32786            32786
# -25          26           26          26            26               26
# ...

# %%
df.pivot_table(index=["Country","Error Message"],aggfunc="count")
# Out:
#                                                               Area Name  \
# Country              Error Message
# AFGHANISTAN          Address Is Incomplete                            0
#                      Call Loop Detected                               0
#                      Call has been canceled by calling party          0
#                      Destination Is Forbidden                         0
#                      Insufficient Balance                             0
#                      Loss Protection                                  0
#                      OK                                               0
# ALBANIA              Call has been canceled by calling party          0
# ALGERIA              Call has been canceled by calling party          0
#                      Insufficient Balance                             0
#                      OK                                               0
# ...

# %%
df = pd.read_excel("ARIAFONE-04-09-2018-16-17-clientrates-133-AZ.xlsx")

# %%
df[df["Unnamed: 1"] == 30210375]
# Out:
# Empty DataFrame
# Columns: [INFO-Telecom, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5]
# Index: []

# %%
df.head()
# Out:
#          INFO-Telecom Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5
# 0                 NaN        NaN        NaN        NaN         NaN        NaN
# 1         DESTINATION     PREFIX       RATE       CURR    EFF DATE       NOTE
# 2         Afghanistan         93     0.1341        EUR  2018-09-11   decrease
# 3  Afghanistan Mobile       9375     0.1391        EUR  2018-08-22       same
# 4  Afghanistan Mobile       9374     0.1391        EUR  2018-08-22       same
