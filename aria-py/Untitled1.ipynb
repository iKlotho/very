# %%
import pandas as pd
import numpy as np

# %%
import json

# %%
with open("logs.json","r") as r :
    ver = json.load(r)

# %%
df = pd.DataFrame.from_dict(ver["filtered_logs"])

# %%
df
# Out:
#       action country                 date  \
# 0         up     AFG  2018-08-21 08:10:39
# 1    unblock     PAK  2018-08-21 08:15:19
# 2         up     PAK  2018-08-21 08:15:59
# 3       down     BGD  2018-08-21 08:21:26
# 4         up     YEM  2018-08-21 09:11:35
# 5       down     PAK  2018-08-21 09:12:48
# 6         up     PAK  2018-08-21 09:14:33
# 7         up     NGA  2018-08-21 09:15:57
# 8       down     PAK  2018-08-21 09:17:20
# 9         up     YEM  2018-08-21 10:12:52
# 10      down     YEM  2018-08-21 10:13:03
# 11        up     PAK  2018-08-21 10:17:21
# 12        up     PHL  2018-08-21 10:17:58
# 13      down     PHL  2018-08-21 10:18:19
# 14      down     UZB  2018-08-21 11:15:50
# 15        up     AFG  2018-08-21 11:17:46
# 16   unblock     PAK  2018-08-21 11:18:30
# 17     block     PAK  2018-08-21 11:18:42
# 18        up     PAK  2018-08-21 11:22:09
# 19        up     IRN  2018-08-21 11:23:37
# 20      down     GRC  2018-08-21 11:24:54
# ...
