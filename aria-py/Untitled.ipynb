# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
plt.style.use("ggplot")

# %%
df = pd.read_excel("C:\\Users\\UMUT\\Downloads\\Call_Analysis_2018-08-30_2018-08-30.xlsx")

# %%
df.head()
# Out:
#    Destination  Prefix Vendor Target   TC   SC  Min  ACD   ASR  Blended
# 0  Afghanistan    93.0    NaN      5  4.0  0.0  0.0    0  0,00     0.16
# 2          NaN     NaN    NaN    NaN  NaN  NaN  NaN  NaN   NaN      NaN
# 4          NaN     NaN    NaN    NaN  NaN  NaN  NaN  NaN   NaN      NaN
# 6          NaN     NaN    NaN    NaN  NaN  NaN  NaN  NaN   NaN      NaN
# 8          NaN     NaN    NaN    NaN  NaN  NaN  NaN  NaN   NaN      NaN

# %%
df[[""]].stack().str.replace(',','.')
# Out:
# 0     Destination            Afghanistan
#       Prefix                         NaN
#       Target                         NaN
#       TC                             NaN
#       SC                             NaN
#       Min                            NaN
#       ACD                            NaN
#       ASR                           0.00
#       Blended                        NaN
# 13    Destination            Afghanistan
#       Prefix                         NaN
#       Target                         NaN
#       TC                             NaN
#       SC                             NaN
#       Min                            NaN
#       ACD                            NaN
#       ASR                           0.00
#       Blended                        NaN
# 24    Destination            Afghanistan
#       Prefix                         NaN
#       Target                         NaN
#       TC                             NaN
#       SC                             NaN
# ...

# %%
df.apply(lambda x: x.str.replace(',','.'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-10b20a44d242> in <module>()
# ----> 1 df.apply(lambda x: x.str.replace(',','.'))
#
# C:\Users\UMUT\Miniconda3\envs\py36\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# C:\Users\UMUT\Miniconda3\envs\py36\lib\site-packages\pandas\core\apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# C:\Users\UMUT\Miniconda3\envs\py36\lib\site-packages\pandas\core\apply.py in get_result(self)
# ...

# %%
df.head()
# Out:
#    Destination  Prefix            Vendor Target   TC   SC  Min  ACD   ASR  \
# 0  Afghanistan    93.0               NaN      5  4.0  0.0  0.0    0  0,00
# 1      Details     NaN  VENTATELE PRE 32    NaN  4.0  0.0  0.0    0  0,00
# 2          NaN     NaN               NaN    NaN  NaN  NaN  NaN  NaN   NaN
# 3      Details     NaN           TATA 26    NaN  4.0  0.0  0.0    0  0,00
# 4          NaN     NaN               NaN    NaN  NaN  NaN  NaN  NaN   NaN
#
#    Blended
# 0   0.1600
# 1   0.1600
# 2      NaN
# 3   0.1747
# 4      NaN

# %%
df[["TC","SC","Min","ASR","Blended"]].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src\inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "0,00"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-3b2080570f6d> in <module>()
# ----> 1 df[["TC","SC","Min","ASR","Blended"]].apply(pd.to_numeric)
#
# C:\Users\UMUT\Miniconda3\envs\py36\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# C:\Users\UMUT\Miniconda3\envs\py36\lib\site-packages\pandas\core\apply.py in get_result(self)
# ...

# %%
df = df[(df.Destination != "Details") & (df.Destination != "Loading...")]

# %%
countries = df.Destination.str.split(' -').str[0]

# %%
ldf = df[df.Destination.isin(countries)]

# %%
df.Destination = countries

# %%
ldf = df.groupby(["Destination"]).sum()[["TC","SC"]]

# %%
top10_dest = ldf.sort_values(by="TC",ascending=False)[1:100]

# %%
top10_dest.plot()

# %%
ldf.sort_values(by="TC",ascending=False)[1:10].plot(kind="bar")

# %%
ldf

# %%
top10_dest["TC"].plot(kind="bar")
top10_sc.plot(kind="bar")

# %%
top10_sc = ldf.sort_values(by="SC",ascending=False)[1:10]["SC"]

# %%
top10_sc.plot(kind="bar",stacked=True)

# %%
 df.groupby(["Destination"]).sum()
# Out:
#                                 Prefix       TC      SC       Min  Blended
# Destination
# Afghanistan                    65720.0  23271.0  4282.0  13075.06   0.5982
# Algeria                        21377.0      1.0     0.0      0.00   0.3046
# American Samoa                  1684.0      6.0     0.0      0.00   0.0405
# Argentina                         54.0      6.0     0.0      0.00   0.0230
# Armenia                        37494.0      4.0     0.0      0.00   0.1760
# Australia                     129072.0     44.0    10.0    100.00   0.0759
# Austria                        43693.0      6.0     0.0      0.00   0.2793
# Azerbaijan                    299311.0     12.0     5.0     27.04   0.7528
# Bahrain                      1169313.0     14.0     0.0      0.00   0.3760
# Bangladesh                      8801.0     55.0    31.0    164.06   0.0243
# Belgium                           32.0      3.0     2.0      0.14   0.0121
# ...

# %%
ldf.to_n
# Out:
# Destination     object
# Prefix         float64
# Vendor          object
# Target          object
# TC             float64
# SC             float64
# Min            float64
# ACD             object
# ASR             object
# Blended        float64
# dtype: object

# %%
dfc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-6f29dc1f4d1a> in <module>()
# ----> 1 dfc
#
# NameError: name 'dfc' is not defined
