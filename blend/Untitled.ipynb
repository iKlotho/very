# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
blend_old = pd.read_excel("blend-eski.xlsx")
blend_new = pd.read_excel("blend-yeni.xlsx")

# %%
blend_old = blend_old.dropna(how='all')

# %%
blend_old[blend_old["Destination"] == "Details"]["Destination"].replace("Details",np.NaN,inplace=True)
# Out:
# C:\Users\UMUT\Miniconda3\envs\py36\lib\site-packages\pandas\core\generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
blend_old["Destination"].fillna(method="backfill")
# Out:
# 0                 Afghanistan - Mobile - MTN
# 1                                    Details
# 3                                    Details
# 5                                    Details
# 7                                    Details
# 9            Afghanistan - Mobile - Etisalat
# 10                                   Details
# 12                                   Details
# 14                                   Details
# 16                                   Details
# 18                                   Details
# 20                                   Details
# 22                                   Details
# 24                                   Details
# 26                                   Details
# 28                                   Details
# 30                                   Details
# 32                                   Details
# 34                                   Details
# 36                     Turkey - North Cyprus
# 37                                   Details
# ...

# %%
blend_old
# Out:
#                                Destination       Prefix  \
# 0               Afghanistan - Mobile - MTN  93770274091
# 1                                  Details          NaN
# 3                                  Details          NaN
# 5                                  Details          NaN
# 7                                  Details          NaN
# 9          Afghanistan - Mobile - Etisalat         9378
# 10                                 Details          NaN
# 12                                 Details          NaN
# 14                                 Details          NaN
# 16                                 Details          NaN
# 18                                 Details          NaN
# 20                                 Details          NaN
# 22                                 Details          NaN
# 24                                 Details          NaN
# 26                                 Details          NaN
# 28                                 Details          NaN
# ...
